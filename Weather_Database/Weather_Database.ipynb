# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 775

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []


# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | najran
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | onda
# Processing Record 7 of Set 1 | peniche
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | camapua
# Processing Record 11 of Set 1 | velingara
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | salinopolis
# Processing Record 21 of Set 1 | gobabis
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | callaway
# Processing Record 27 of Set 1 | caxito
# Processing Record 28 of Set 1 | donskoye
# Processing Record 29 of Set 1 | odweyne
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 1 | necochea
# Processing Record 35 of Set 1 | hualmay
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | henties bay
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | beloha
# Processing Record 46 of Set 1 | sikeston
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | mani
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | ambilobe
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | viedma
# Processing Record 6 of Set 2 | bolshiye saly
# City not found. Skipping...
# Processing Record 7 of Set 2 | alexandria
# Processing Record 8 of Set 2 | high rock
# Processing Record 9 of Set 2 | lavras
# Processing Record 10 of Set 2 | ogaminana
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | veraval
# Processing Record 14 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 2 | inirida
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | san-pedro
# Processing Record 18 of Set 2 | sinjar
# Processing Record 19 of Set 2 | coxim
# Processing Record 20 of Set 2 | sovetskiy
# Processing Record 21 of Set 2 | sept-iles
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | urengoy
# Processing Record 24 of Set 2 | mangrol
# Processing Record 25 of Set 2 | aksu
# Processing Record 26 of Set 2 | dakar
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | lichinga
# Processing Record 29 of Set 2 | ankazoabo
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | caucaia
# Processing Record 35 of Set 2 | aquiraz
# Processing Record 36 of Set 2 | talas
# Processing Record 37 of Set 2 | lumberton
# Processing Record 38 of Set 2 | oranjemund
# Processing Record 39 of Set 2 | xanlar
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | pangnirtung
# Processing Record 43 of Set 2 | boone
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | tucurui
# Processing Record 46 of Set 2 | ciudad bolivar
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | korla
# Processing Record 49 of Set 2 | waddan
# Processing Record 50 of Set 2 | padang
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | ovruch
# Processing Record 4 of Set 3 | canar
# Processing Record 5 of Set 3 | paamiut
# Processing Record 6 of Set 3 | kudahuvadhoo
# Processing Record 7 of Set 3 | neuquen
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | la tuque
# Processing Record 10 of Set 3 | axim
# Processing Record 11 of Set 3 | jintur
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | takoradi
# Processing Record 14 of Set 3 | kamachumu
# Processing Record 15 of Set 3 | asyut
# Processing Record 16 of Set 3 | rio gallegos
# Processing Record 17 of Set 3 | maracacume
# Processing Record 18 of Set 3 | porvoo
# Processing Record 19 of Set 3 | leshukonskoye
# Processing Record 20 of Set 3 | narsaq
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | bud
# Processing Record 23 of Set 3 | yarada
# Processing Record 24 of Set 3 | pitkyaranta
# Processing Record 25 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | meulaboh
# Processing Record 28 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 3 | bardiyah
# Processing Record 30 of Set 3 | mount pleasant
# Processing Record 31 of Set 3 | rosiori
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | gazojak
# Processing Record 34 of Set 3 | kostomuksha
# Processing Record 35 of Set 3 | kotli loharan
# Processing Record 36 of Set 3 | leh
# Processing Record 37 of Set 3 | imbituba
# Processing Record 38 of Set 3 | aljezur
# Processing Record 39 of Set 3 | stykkisholmur
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | tres arroyos
# Processing Record 42 of Set 3 | bykovo
# Processing Record 43 of Set 3 | roald
# Processing Record 44 of Set 3 | baghdad
# Processing Record 45 of Set 3 | brae
# Processing Record 46 of Set 3 | sistranda
# Processing Record 47 of Set 3 | abonnema
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | aiken
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | guanica
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | maceio
# Processing Record 7 of Set 4 | aleksandrov gay
# Processing Record 8 of Set 4 | barcelos
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | tinyahuarco
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 4 | liverpool
# Processing Record 14 of Set 4 | trinidad
# Processing Record 15 of Set 4 | goure
# Processing Record 16 of Set 4 | belmonte
# Processing Record 17 of Set 4 | novyy urengoy
# Processing Record 18 of Set 4 | apatity
# Processing Record 19 of Set 4 | shu
# Processing Record 20 of Set 4 | opuwo
# Processing Record 21 of Set 4 | natal
# Processing Record 22 of Set 4 | beyneu
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | bonthe
# Processing Record 25 of Set 4 | huarmey
# Processing Record 26 of Set 4 | raudeberg
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | burica
# City not found. Skipping...
# Processing Record 29 of Set 4 | gambela
# Processing Record 30 of Set 4 | koutiala
# Processing Record 31 of Set 4 | gazni
# City not found. Skipping...
# Processing Record 32 of Set 4 | kamenka
# Processing Record 33 of Set 4 | russkaya polyana
# Processing Record 34 of Set 4 | kalemie
# Processing Record 35 of Set 4 | la mana
# Processing Record 36 of Set 4 | irpa irpa
# Processing Record 37 of Set 4 | lokosovo
# Processing Record 38 of Set 4 | okoneshnikovo
# Processing Record 39 of Set 4 | morondava
# Processing Record 40 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 4 | gambo
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | tromso
# Processing Record 44 of Set 4 | campbeltown
# Processing Record 45 of Set 4 | kondoa
# Processing Record 46 of Set 4 | grindavik
# Processing Record 47 of Set 4 | nueva guinea
# Processing Record 48 of Set 4 | araouane
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 50 of Set 4 | matagami
# Processing Record 1 of Set 5 | altamira
# Processing Record 2 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | riviere-au-renard
# Processing Record 5 of Set 5 | birao
# Processing Record 6 of Set 5 | patitirion
# Processing Record 7 of Set 5 | znamenskoye
# Processing Record 8 of Set 5 | rio claro
# Processing Record 9 of Set 5 | los llanos de aridane
# Processing Record 10 of Set 5 | qaqortoq
# Processing Record 11 of Set 5 | lodwar
# Processing Record 12 of Set 5 | olinda
# Processing Record 13 of Set 5 | grand gaube
# Processing Record 14 of Set 5 | fasa
# Processing Record 15 of Set 5 | walvis bay
# Processing Record 16 of Set 5 | west bay
# Processing Record 17 of Set 5 | sulina
# Processing Record 18 of Set 5 | anori
# Processing Record 19 of Set 5 | kankon
# Processing Record 20 of Set 5 | mingaora
# Processing Record 21 of Set 5 | cleethorpes
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | maunabo
# Processing Record 24 of Set 5 | san pedro
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | sankt wendel
# Processing Record 27 of Set 5 | marinette
# Processing Record 28 of Set 5 | america dourada
# Processing Record 29 of Set 5 | husavik
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | skibbereen
# Processing Record 32 of Set 5 | reconquista
# Processing Record 33 of Set 5 | cochabamba
# Processing Record 34 of Set 5 | vagur
# Processing Record 35 of Set 5 | bambous virieux
# Processing Record 36 of Set 5 | mao
# Processing Record 37 of Set 5 | yenagoa
# Processing Record 38 of Set 5 | marrakesh
# Processing Record 39 of Set 5 | taoudenni
# Processing Record 40 of Set 5 | bourg-en-bresse
# Processing Record 41 of Set 5 | bosanska gradiska
# Processing Record 42 of Set 5 | urucurituba
# Processing Record 43 of Set 5 | sikonge
# Processing Record 44 of Set 5 | mirnyy
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | bonito
# Processing Record 47 of Set 5 | pucallpa
# Processing Record 48 of Set 5 | coihaique
# Processing Record 49 of Set 5 | dudinka
# Processing Record 50 of Set 5 | muros
# Processing Record 1 of Set 6 | chesma
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | uruana
# Processing Record 4 of Set 6 | piacabucu
# Processing Record 5 of Set 6 | udimskiy
# Processing Record 6 of Set 6 | abu dhabi
# Processing Record 7 of Set 6 | siniscola
# Processing Record 8 of Set 6 | junqueiro
# Processing Record 9 of Set 6 | huntingdon
# Processing Record 10 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 6 | nueve de julio
# Processing Record 12 of Set 6 | cape coast
# Processing Record 13 of Set 6 | tacoronte
# Processing Record 14 of Set 6 | dubai
# Processing Record 15 of Set 6 | oksfjord
# Processing Record 16 of Set 6 | finnsnes
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | chokwe
# Processing Record 19 of Set 6 | gonen
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | praia da vitoria
# Processing Record 22 of Set 6 | sinop
# Processing Record 23 of Set 6 | havelock
# Processing Record 24 of Set 6 | exu
# Processing Record 25 of Set 6 | brentwood
# Processing Record 26 of Set 6 | berlevag
# Processing Record 27 of Set 6 | gamba
# Processing Record 28 of Set 6 | surskoye
# Processing Record 29 of Set 6 | tazovskiy
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | millau
# Processing Record 32 of Set 6 | salinas
# Processing Record 33 of Set 6 | menzelinsk
# Processing Record 34 of Set 6 | benghazi
# Processing Record 35 of Set 6 | umm lajj
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | viransehir
# Processing Record 38 of Set 6 | ajdabiya
# Processing Record 39 of Set 6 | adrar
# Processing Record 40 of Set 6 | tema
# Processing Record 41 of Set 6 | kilindoni
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | rocha
# Processing Record 44 of Set 6 | skiros
# City not found. Skipping...
# Processing Record 45 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 46 of Set 6 | riberalta
# Processing Record 47 of Set 6 | yar-sale
# Processing Record 48 of Set 6 | muscat
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 7 | bojnurd
# Processing Record 2 of Set 7 | frolovo
# Processing Record 3 of Set 7 | nosy varika
# Processing Record 4 of Set 7 | rudbar
# Processing Record 5 of Set 7 | mezen
# Processing Record 6 of Set 7 | cumberland
# Processing Record 7 of Set 7 | areia branca
# Processing Record 8 of Set 7 | san carlos de bariloche
# Processing Record 9 of Set 7 | katyuzhanka
# Processing Record 10 of Set 7 | krasnoyarskiy
# Processing Record 11 of Set 7 | san felipe
# Processing Record 12 of Set 7 | xuddur
# Processing Record 13 of Set 7 | elbistan
# Processing Record 14 of Set 7 | soyo
# Processing Record 15 of Set 7 | ormara
# Processing Record 16 of Set 7 | uyemskiy
# Processing Record 17 of Set 7 | valdivia
# Processing Record 18 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 7 | sao felix do xingu
# Processing Record 20 of Set 7 | uromi
# Processing Record 21 of Set 7 | awbari
# Processing Record 22 of Set 7 | hjelset
# Processing Record 23 of Set 7 | riyadh
# Processing Record 24 of Set 7 | skelleftea
# Processing Record 25 of Set 7 | the valley
# Processing Record 26 of Set 7 | kargasok
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | jizan
# Processing Record 29 of Set 7 | makinsk
# Processing Record 30 of Set 7 | kavaratti
# Processing Record 31 of Set 7 | ilhabela
# Processing Record 32 of Set 7 | darayya
# Processing Record 33 of Set 7 | notodden
# Processing Record 34 of Set 7 | ubala
# Processing Record 35 of Set 7 | candido mendes
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | port-cartier
# Processing Record 38 of Set 7 | vyartsilya
# Processing Record 39 of Set 7 | passos
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | mahanoro
# Processing Record 42 of Set 7 | mogadishu
# Processing Record 43 of Set 7 | ouango
# Processing Record 44 of Set 7 | haverfordwest
# Processing Record 45 of Set 7 | orje
# Processing Record 46 of Set 7 | maldonado
# Processing Record 47 of Set 7 | kalmunai
# Processing Record 48 of Set 7 | arica
# Processing Record 49 of Set 7 | myrtle grove
# Processing Record 50 of Set 7 | moose factory
# Processing Record 1 of Set 8 | mansa
# Processing Record 2 of Set 8 | churhat
# Processing Record 3 of Set 8 | susangerd
# Processing Record 4 of Set 8 | cayenne
# Processing Record 5 of Set 8 | mitsamiouli
# Processing Record 6 of Set 8 | ferkessedougou
# Processing Record 7 of Set 8 | salamiyah
# Processing Record 8 of Set 8 | shetpe
# Processing Record 9 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 8 | urucara
# Processing Record 11 of Set 8 | tsabong
# Processing Record 12 of Set 8 | kemi
# Processing Record 13 of Set 8 | urumqi
# Processing Record 14 of Set 8 | bubaque
# Processing Record 15 of Set 8 | bestobe
# Processing Record 16 of Set 8 | jutai
# Processing Record 17 of Set 8 | synya
# Processing Record 18 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 8 | itupiranga
# Processing Record 20 of Set 8 | ayorou
# Processing Record 21 of Set 8 | navalmoral de la mata
# Processing Record 22 of Set 8 | oksovskiy
# Processing Record 23 of Set 8 | santa catalina
# Processing Record 24 of Set 8 | thompson
# Processing Record 25 of Set 8 | tombouctou
# Processing Record 26 of Set 8 | kefalovrison
# City not found. Skipping...
# Processing Record 27 of Set 8 | matane
# Processing Record 28 of Set 8 | rosa zarate
# Processing Record 29 of Set 8 | pahalgam
# Processing Record 30 of Set 8 | dalbandin
# Processing Record 31 of Set 8 | yining
# Processing Record 32 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 8 | itarema
# Processing Record 34 of Set 8 | stornoway
# Processing Record 35 of Set 8 | belyy yar
# Processing Record 36 of Set 8 | turukhansk
# Processing Record 37 of Set 8 | oxford
# Processing Record 38 of Set 8 | marawi
# Processing Record 39 of Set 8 | misratah
# Processing Record 40 of Set 8 | gazli
# Processing Record 41 of Set 8 | rorvik
# Processing Record 42 of Set 8 | utrecht
# Processing Record 43 of Set 8 | sao jose da coroa grande
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | coshocton
# Processing Record 47 of Set 8 | sao filipe
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | labrea
# Processing Record 50 of Set 8 | atar
# Processing Record 1 of Set 9 | malaya serdoba
# Processing Record 2 of Set 9 | damaturu
# Processing Record 3 of Set 9 | mayumba
# Processing Record 4 of Set 9 | salisbury
# Processing Record 5 of Set 9 | hofn
# Processing Record 6 of Set 9 | senanga
# Processing Record 7 of Set 9 | mocuba
# Processing Record 8 of Set 9 | kidodi
# Processing Record 9 of Set 9 | boden
# Processing Record 10 of Set 9 | skjervoy
# Processing Record 11 of Set 9 | shache
# Processing Record 12 of Set 9 | ponta delgada
# Processing Record 13 of Set 9 | nsoko
# Processing Record 14 of Set 9 | alta floresta
# Processing Record 15 of Set 9 | joensuu
# Processing Record 16 of Set 9 | calama
# Processing Record 17 of Set 9 | vicuna
# Processing Record 18 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 9 | syumsi
# Processing Record 20 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 9 | clones
# Processing Record 22 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 9 | formosa
# Processing Record 24 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 9 | mamontovo
# Processing Record 26 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 9 | griffin
# Processing Record 28 of Set 9 | port hawkesbury
# Processing Record 29 of Set 9 | mayor pablo lagerenza
# Processing Record 30 of Set 9 | lehigh acres
# Processing Record 31 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 9 | muzhi
# Processing Record 33 of Set 9 | monrovia
# Processing Record 34 of Set 9 | urambo
# Processing Record 35 of Set 9 | nadym
# Processing Record 36 of Set 9 | vila velha
# Processing Record 37 of Set 9 | ghanzi
# Processing Record 38 of Set 9 | canico
# Processing Record 39 of Set 9 | toro
# Processing Record 40 of Set 9 | sorland
# Processing Record 41 of Set 9 | storslett
# Processing Record 42 of Set 9 | tiznit
# Processing Record 43 of Set 9 | abnub
# Processing Record 44 of Set 9 | rosita
# Processing Record 45 of Set 9 | les cayes
# Processing Record 46 of Set 9 | mineralnyye vody
# Processing Record 47 of Set 9 | bracciano
# Processing Record 48 of Set 9 | reo
# Processing Record 49 of Set 9 | dwarka
# Processing Record 50 of Set 9 | novoagansk
# Processing Record 1 of Set 10 | la palma
# Processing Record 2 of Set 10 | san javier
# Processing Record 3 of Set 10 | kathmandu
# Processing Record 4 of Set 10 | saint-pierre
# Processing Record 5 of Set 10 | galle
# Processing Record 6 of Set 10 | iberia
# Processing Record 7 of Set 10 | vangaindrano
# Processing Record 8 of Set 10 | chapais
# Processing Record 9 of Set 10 | thinadhoo
# Processing Record 10 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 10 | cap malheureux
# Processing Record 12 of Set 10 | benjamin aceval
# Processing Record 13 of Set 10 | kongolo
# Processing Record 14 of Set 10 | nyrob
# Processing Record 15 of Set 10 | idah
# Processing Record 16 of Set 10 | bida
# Processing Record 17 of Set 10 | hobyo
# Processing Record 18 of Set 10 | marsh harbour
# Processing Record 19 of Set 10 | rio bueno
# Processing Record 20 of Set 10 | sembe
# Processing Record 21 of Set 10 | plettenberg bay
# Processing Record 22 of Set 10 | sarkand
# Processing Record 23 of Set 10 | mitu
# Processing Record 24 of Set 10 | altagracia de orituco
# Processing Record 25 of Set 10 | tisovec
# Processing Record 26 of Set 10 | humaita
# Processing Record 27 of Set 10 | catabola
# Processing Record 28 of Set 10 | kuloy
# Processing Record 29 of Set 10 | maniitsoq
# Processing Record 30 of Set 10 | alpinopolis
# Processing Record 31 of Set 10 | gorahun
# Processing Record 32 of Set 10 | camacupa
# Processing Record 33 of Set 10 | andenes
# Processing Record 34 of Set 10 | verkhnyaya sysert
# Processing Record 35 of Set 10 | wadhwan
# City not found. Skipping...
# Processing Record 36 of Set 10 | knysna
# Processing Record 37 of Set 10 | golitsyno
# Processing Record 38 of Set 10 | azar shahr
# City not found. Skipping...
# Processing Record 39 of Set 10 | gao
# Processing Record 40 of Set 10 | kambove
# Processing Record 41 of Set 10 | zhytomyr
# Processing Record 42 of Set 10 | balad
# Processing Record 43 of Set 10 | benguela
# Processing Record 44 of Set 10 | berasia
# Processing Record 45 of Set 10 | myra
# Processing Record 46 of Set 10 | tatarsk
# Processing Record 47 of Set 10 | zheleznovodsk
# Processing Record 48 of Set 10 | channel-port aux basques
# Processing Record 49 of Set 10 | civitavecchia
# Processing Record 50 of Set 10 | sakrand
# Processing Record 1 of Set 11 | kassala
# Processing Record 2 of Set 11 | luena
# Processing Record 3 of Set 11 | cascais
# Processing Record 4 of Set 11 | tazmalt
# Processing Record 5 of Set 11 | guaratinga
# Processing Record 6 of Set 11 | oktyabrskiy
# Processing Record 7 of Set 11 | eyl
# Processing Record 8 of Set 11 | akdepe
# Processing Record 9 of Set 11 | mponela
# Processing Record 10 of Set 11 | hammerfest
# Processing Record 11 of Set 11 | ritchie
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | upington
# Processing Record 14 of Set 11 | mumford
# Processing Record 15 of Set 11 | denia
# Processing Record 16 of Set 11 | sarnia
# Processing Record 17 of Set 11 | iralaya
# Processing Record 18 of Set 11 | komatipoort
# Processing Record 19 of Set 11 | puerto maldonado
# Processing Record 20 of Set 11 | kutum
# Processing Record 21 of Set 11 | santiago
# Processing Record 22 of Set 11 | tias
# Processing Record 23 of Set 11 | modrica
# Processing Record 24 of Set 11 | octeville
# Processing Record 25 of Set 11 | bechem
# Processing Record 26 of Set 11 | asosa
# Processing Record 27 of Set 11 | marienburg
# Processing Record 28 of Set 11 | havoysund
# Processing Record 29 of Set 11 | bathurst
# Processing Record 30 of Set 11 | atbasar
# Processing Record 31 of Set 11 | tornio
# Processing Record 32 of Set 11 | nioro
# Processing Record 33 of Set 11 | watsa
# Processing Record 34 of Set 11 | nicoya
# Processing Record 35 of Set 11 | igarka
# Processing Record 36 of Set 11 | timmins
# Processing Record 37 of Set 11 | zhukovka
# Processing Record 38 of Set 11 | crotone
# Processing Record 39 of Set 11 | turkistan
# Processing Record 40 of Set 11 | skagen
# Processing Record 41 of Set 11 | dawlatabad
# Processing Record 42 of Set 11 | melchor de mencos
# Processing Record 43 of Set 11 | zhezkazgan
# Processing Record 44 of Set 11 | avila
# Processing Record 45 of Set 11 | fort-shevchenko
# Processing Record 46 of Set 11 | aykino
# Processing Record 47 of Set 11 | nyuksenitsa
# Processing Record 48 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 49 of Set 11 | puerto ayacucho
# Processing Record 50 of Set 11 | keti bandar
# Processing Record 1 of Set 12 | mabaruma
# Processing Record 2 of Set 12 | mozarlandia
# Processing Record 3 of Set 12 | dehloran
# Processing Record 4 of Set 12 | monterrey
# Processing Record 5 of Set 12 | mbanza-ngungu
# Processing Record 6 of Set 12 | kedgwick
# Processing Record 7 of Set 12 | port said
# Processing Record 8 of Set 12 | george
# Processing Record 9 of Set 12 | x-can
# City not found. Skipping...
# Processing Record 10 of Set 12 | petrozavodsk
# Processing Record 11 of Set 12 | sao domingos
# Processing Record 12 of Set 12 | vestmanna
# Processing Record 13 of Set 12 | balao
# Processing Record 14 of Set 12 | male
# Processing Record 15 of Set 12 | olonets
# Processing Record 16 of Set 12 | quelimane
# Processing Record 17 of Set 12 | ust-charyshskaya pristan
# Processing Record 18 of Set 12 | santa isabel do rio negro
# Processing Record 19 of Set 12 | igrim
# Processing Record 20 of Set 12 | puerto colombia
# Processing Record 21 of Set 12 | laharpur
# Processing Record 22 of Set 12 | garissa
# Processing Record 23 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 12 | abu samrah
# Processing Record 25 of Set 12 | cassilandia
# Processing Record 26 of Set 12 | ust-tsilma
# Processing Record 27 of Set 12 | kroonstad
# Processing Record 28 of Set 12 | manta
# Processing Record 29 of Set 12 | kannur
# Processing Record 30 of Set 12 | bhanpura
# Processing Record 31 of Set 12 | sur
# Processing Record 32 of Set 12 | peachtree city
# Processing Record 33 of Set 12 | borama
# City not found. Skipping...
# Processing Record 34 of Set 12 | upata
# Processing Record 35 of Set 12 | sisimiut
# Processing Record 36 of Set 12 | sakakah
# Processing Record 37 of Set 12 | wavre
# Processing Record 38 of Set 12 | dale
# Processing Record 39 of Set 12 | wick
# Processing Record 40 of Set 12 | sigayevo
# Processing Record 41 of Set 12 | zaltan
# Processing Record 42 of Set 12 | nizwa
# Processing Record 43 of Set 12 | huicungo
# Processing Record 44 of Set 12 | may pen
# Processing Record 45 of Set 12 | troitsko-pechorsk
# Processing Record 46 of Set 12 | iaciara
# Processing Record 47 of Set 12 | diu
# Processing Record 48 of Set 12 | kuito
# Processing Record 49 of Set 12 | lubango
# Processing Record 50 of Set 12 | bronderslev
# Processing Record 1 of Set 13 | erzincan
# Processing Record 2 of Set 13 | vianopolis
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | portobelo
# Processing Record 5 of Set 13 | zanjan
# Processing Record 6 of Set 13 | san juan
# Processing Record 7 of Set 13 | palkaka
# City not found. Skipping...
# Processing Record 8 of Set 13 | mubende
# Processing Record 9 of Set 13 | vysotsk
# Processing Record 10 of Set 13 | antofagasta
# Processing Record 11 of Set 13 | pali
# Processing Record 12 of Set 13 | nuevitas
# Processing Record 13 of Set 13 | kindu
# Processing Record 14 of Set 13 | conceicao da barra
# Processing Record 15 of Set 13 | canutama
# Processing Record 16 of Set 13 | derzhavinsk
# Processing Record 17 of Set 13 | kochinda
# Processing Record 18 of Set 13 | san diego
# Processing Record 19 of Set 13 | anloga
# Processing Record 20 of Set 13 | banyo
# Processing Record 21 of Set 13 | calvinia
# Processing Record 22 of Set 13 | aripuana
# Processing Record 23 of Set 13 | kasungu
# Processing Record 24 of Set 13 | gerash
# Processing Record 25 of Set 13 | ballina
# Processing Record 26 of Set 13 | mangaratiba
# Processing Record 27 of Set 13 | herat
# Processing Record 28 of Set 13 | santa cruz
# Processing Record 29 of Set 13 | kismayo
# Processing Record 30 of Set 13 | kankaanpaa
# Processing Record 31 of Set 13 | myronivka
# Processing Record 32 of Set 13 | salekhard
# Processing Record 33 of Set 13 | teya
# Processing Record 34 of Set 13 | paris
# Processing Record 35 of Set 13 | buchanan
# Processing Record 36 of Set 13 | bilma
# Processing Record 37 of Set 13 | akureyri
# Processing Record 38 of Set 13 | sorochinsk
# Processing Record 39 of Set 13 | curuca
# Processing Record 40 of Set 13 | buraydah
# Processing Record 41 of Set 13 | nuuk
# Processing Record 42 of Set 13 | port blair
# Processing Record 43 of Set 13 | sucre
# Processing Record 44 of Set 13 | puerto leguizamo
# Processing Record 45 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 47 of Set 13 | maku
# Processing Record 48 of Set 13 | mpika
# Processing Record 49 of Set 13 | junin
# Processing Record 50 of Set 13 | kizema
# Processing Record 1 of Set 14 | awjilah
# Processing Record 2 of Set 14 | guarapari
# Processing Record 3 of Set 14 | kotelnich
# Processing Record 4 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 14 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 6 of Set 14 | venice
# Processing Record 7 of Set 14 | plouzane
# Processing Record 8 of Set 14 | phalaborwa
# Processing Record 9 of Set 14 | beder
# Processing Record 10 of Set 14 | santa maria
# Processing Record 11 of Set 14 | strezhevoy
# Processing Record 12 of Set 14 | platanos
# Processing Record 13 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 14 | gatehouse of fleet
# Processing Record 15 of Set 14 | muli
# Processing Record 16 of Set 14 | port-gentil
# Processing Record 17 of Set 14 | crown point
# Processing Record 18 of Set 14 | san andres
# Processing Record 19 of Set 14 | richards bay
# Processing Record 20 of Set 14 | requena
# Processing Record 21 of Set 14 | boiro
# Processing Record 22 of Set 14 | porciuncula
# Processing Record 23 of Set 14 | khalkhal
# Processing Record 24 of Set 14 | bhatkal
# Processing Record 25 of Set 14 | paragominas
# Processing Record 26 of Set 14 | puerto del rosario
# Processing Record 27 of Set 14 | babanka
# Processing Record 28 of Set 14 | lekoni
# Processing Record 29 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 14 | torres
# Processing Record 31 of Set 14 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 32 of Set 14 | amot
# Processing Record 33 of Set 14 | vendome
# Processing Record 34 of Set 14 | sol-iletsk
# Processing Record 35 of Set 14 | sao joao da barra
# Processing Record 36 of Set 14 | cullman
# Processing Record 37 of Set 14 | burlatskoye
# Processing Record 38 of Set 14 | sfantu gheorghe
# Processing Record 39 of Set 14 | emet
# Processing Record 40 of Set 14 | alice town
# Processing Record 41 of Set 14 | catamarca
# Processing Record 42 of Set 14 | lahij
# Processing Record 43 of Set 14 | calinesti
# Processing Record 44 of Set 14 | bocana de paiwas
# Processing Record 45 of Set 14 | mapiripan
# Processing Record 46 of Set 14 | albany
# Processing Record 47 of Set 14 | tulum
# Processing Record 48 of Set 14 | yazd
# Processing Record 49 of Set 14 | harper
# Processing Record 50 of Set 14 | semnan
# Processing Record 1 of Set 15 | sarab
# Processing Record 2 of Set 15 | sorkjosen
# Processing Record 3 of Set 15 | trelew
# Processing Record 4 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 15 | tamandare
# Processing Record 6 of Set 15 | nizhniy odes
# Processing Record 7 of Set 15 | nata
# Processing Record 8 of Set 15 | san matias
# Processing Record 9 of Set 15 | moyale
# Processing Record 10 of Set 15 | agropoli
# Processing Record 11 of Set 15 | watford
# Processing Record 12 of Set 15 | chyhyryn
# Processing Record 13 of Set 15 | chalakudi
# Processing Record 14 of Set 15 | porto novo
# Processing Record 15 of Set 15 | sambava
# Processing Record 16 of Set 15 | fomboni
# Processing Record 17 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 15 | pandamatenga
# Processing Record 19 of Set 15 | saint-francois
# Processing Record 20 of Set 15 | marsa matruh
# Processing Record 21 of Set 15 | keuruu
# Processing Record 22 of Set 15 | sohag
# Processing Record 23 of Set 15 | nouadhibou
# Processing Record 24 of Set 15 | lagoa vermelha
# Processing Record 25 of Set 15 | betioky
# Processing Record 26 of Set 15 | madison
# Processing Record 27 of Set 15 | ondangwa
# Processing Record 28 of Set 15 | pokhara
# Processing Record 29 of Set 15 | nakasongola
# Processing Record 30 of Set 15 | lagunas
# Processing Record 31 of Set 15 | hassleholm
# Processing Record 32 of Set 15 | sebinkarahisar
# Processing Record 33 of Set 15 | marsaxlokk
# Processing Record 34 of Set 15 | verkhnyaya inta
# Processing Record 35 of Set 15 | chelbasskaya
# Processing Record 36 of Set 15 | cabo rojo
# Processing Record 37 of Set 15 | conakry
# Processing Record 38 of Set 15 | serpa
# Processing Record 39 of Set 15 | san marcos
# Processing Record 40 of Set 15 | mazamari
# Processing Record 41 of Set 15 | pimentel
# Processing Record 42 of Set 15 | ourinhos
# Processing Record 43 of Set 15 | willowmore
# Processing Record 44 of Set 15 | timra
# Processing Record 45 of Set 15 | itacarambi
# Processing Record 46 of Set 15 | grootfontein
# Processing Record 47 of Set 15 | karatau
# Processing Record 48 of Set 15 | tessalit
# Processing Record 49 of Set 15 | ilinskiy
# Processing Record 50 of Set 15 | sharlyk
# Processing Record 1 of Set 16 | bredy
# Processing Record 2 of Set 16 | bekhteyevka
# Processing Record 3 of Set 16 | nanga eboko
# Processing Record 4 of Set 16 | antananarivo
# Processing Record 5 of Set 16 | isla mujeres
# Processing Record 6 of Set 16 | balkhash
# Processing Record 7 of Set 16 | kasongo-lunda
# Processing Record 8 of Set 16 | sabzevar
# Processing Record 9 of Set 16 | turayf
# Processing Record 10 of Set 16 | rurrenabaque
# Processing Record 11 of Set 16 | mahon
# Processing Record 12 of Set 16 | batticaloa
# Processing Record 13 of Set 16 | buritis
# Processing Record 14 of Set 16 | betul
# Processing Record 15 of Set 16 | mortka
# Processing Record 16 of Set 16 | rincon
# Processing Record 17 of Set 16 | am timan
# Processing Record 18 of Set 16 | afsin
# Processing Record 19 of Set 16 | muzaffarabad
# Processing Record 20 of Set 16 | wattegama
# Processing Record 21 of Set 16 | quilmana
# Processing Record 22 of Set 16 | angoche
# Processing Record 23 of Set 16 | micheweni
# Processing Record 24 of Set 16 | tonekabon
# Processing Record 25 of Set 16 | lujan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 723

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Mahebourg -20.4081   57.7000     74.25        88          40        5.75
# 1      Iqaluit  63.7506  -68.5145     22.73        93         100       46.04
# 2       Najran  17.4924   44.1277     68.65        22           2        3.31
# 3    Busselton -33.6500  115.3333     51.75        75          56       12.73
# 4     Tasiilaq  65.6145  -37.6368     39.36        72         100        1.97
# 5         Onda  39.9667   -0.2500     68.90        84          96        0.72
# 6      Peniche  39.3558   -9.3811     71.08        80         100       19.30
# 7  Port Alfred -33.5906   26.8910     64.18        77         100        4.00
# 8     Saldanha -33.0117   17.9442     63.21        83          79       10.36
# 9      Camapua -19.5314  -54.0439     92.79        35          63        4.72
#
#   Country                 Date
# 0      MU  2022-10-28 18:20:10
# 1      CA  2022-10-28 18:20:10
# 2      SA  2022-10-28 18:16:56
# 3      AU  2022-10-28 18:20:12
# 4      GL  2022-10-28 18:20:12
# 5      ES  2022-10-28 18:20:13
# 6      PT  2022-10-28 18:20:13
# 7      ZA  2022-10-28 18:20:14
# 8      ZA  2022-10-28 18:20:15
# 9      BR  2022-10-28 18:20:16

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Mahebourg      MU  2022-10-28 18:20:10 -20.4081   57.7000     74.25
# 1      Iqaluit      CA  2022-10-28 18:20:10  63.7506  -68.5145     22.73
# 2       Najran      SA  2022-10-28 18:16:56  17.4924   44.1277     68.65
# 3    Busselton      AU  2022-10-28 18:20:12 -33.6500  115.3333     51.75
# 4     Tasiilaq      GL  2022-10-28 18:20:12  65.6145  -37.6368     39.36
# 5         Onda      ES  2022-10-28 18:20:13  39.9667   -0.2500     68.90
# 6      Peniche      PT  2022-10-28 18:20:13  39.3558   -9.3811     71.08
# 7  Port Alfred      ZA  2022-10-28 18:20:14 -33.5906   26.8910     64.18
# 8     Saldanha      ZA  2022-10-28 18:20:15 -33.0117   17.9442     63.21
# 9      Camapua      BR  2022-10-28 18:20:16 -19.5314  -54.0439     92.79
#
#    Humidity  Cloudiness  Wind Speed
# 0        88          40        5.75
# 1        93         100       46.04
# 2        22           2        3.31
# 3        75          56       12.73
# 4        72         100        1.97
# 5        84          96        0.72
# 6        80         100       19.30
# 7        77         100        4.00
# 8        83          79       10.36
# 9        35          63        4.72

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = " WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="Index")
