# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 774

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []


# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | suamico
# Processing Record 3 of Set 1 | bartica
# Processing Record 4 of Set 1 | bilma
# Processing Record 5 of Set 1 | bronnoysund
# Processing Record 6 of Set 1 | key west
# Processing Record 7 of Set 1 | pervomaysk
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | muros
# Processing Record 10 of Set 1 | cayenne
# Processing Record 11 of Set 1 | paamiut
# Processing Record 12 of Set 1 | sakakah
# Processing Record 13 of Set 1 | tiznit
# Processing Record 14 of Set 1 | oktyabrskoye
# Processing Record 15 of Set 1 | tanout
# Processing Record 16 of Set 1 | tucurui
# Processing Record 17 of Set 1 | creemore
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | ostrovnoy
# Processing Record 22 of Set 1 | amapa
# Processing Record 23 of Set 1 | angren
# Processing Record 24 of Set 1 | sorland
# Processing Record 25 of Set 1 | yozgat
# Processing Record 26 of Set 1 | shenavan
# Processing Record 27 of Set 1 | backi jarak
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | san antero
# Processing Record 30 of Set 1 | carballo
# Processing Record 31 of Set 1 | temiscaming
# Processing Record 32 of Set 1 | bhinmal
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | trapani
# Processing Record 36 of Set 1 | demba
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | kaz
# Processing Record 40 of Set 1 | santiago del estero
# Processing Record 41 of Set 1 | glubokoe
# City not found. Skipping...
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | anastacio
# Processing Record 46 of Set 1 | zyryanovsk
# Processing Record 47 of Set 1 | umm kaddadah
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | mbandaka
# Processing Record 1 of Set 2 | kambove
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | moroto
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | saint-francois
# Processing Record 8 of Set 2 | cap malheureux
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | faya
# Processing Record 11 of Set 2 | bandarbeyla
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | hit
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | nchelenge
# Processing Record 22 of Set 2 | danielskuil
# Processing Record 23 of Set 2 | royan
# Processing Record 24 of Set 2 | avallon
# Processing Record 25 of Set 2 | umm lajj
# Processing Record 26 of Set 2 | massaguet
# Processing Record 27 of Set 2 | inhambane
# Processing Record 28 of Set 2 | paragominas
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | ambatofinandrahana
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | mezen
# Processing Record 33 of Set 2 | kourou
# Processing Record 34 of Set 2 | bereznik
# Processing Record 35 of Set 2 | mecca
# Processing Record 36 of Set 2 | necochea
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | villa del rosario
# Processing Record 40 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 2 | gollere
# City not found. Skipping...
# Processing Record 42 of Set 2 | tirlyanskiy
# Processing Record 43 of Set 2 | ankazoabo
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | soyo
# Processing Record 47 of Set 2 | volchikha
# Processing Record 48 of Set 2 | maloy
# Processing Record 49 of Set 2 | carutapera
# Processing Record 50 of Set 2 | buraydah
# Processing Record 1 of Set 3 | manono
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | ormond beach
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 3 | kapoeta
# Processing Record 8 of Set 3 | blagoyevo
# Processing Record 9 of Set 3 | constitucion
# Processing Record 10 of Set 3 | porto novo
# Processing Record 11 of Set 3 | belmonte
# Processing Record 12 of Set 3 | camacha
# Processing Record 13 of Set 3 | kandi
# Processing Record 14 of Set 3 | pesaro
# Processing Record 15 of Set 3 | kidal
# Processing Record 16 of Set 3 | altamira
# Processing Record 17 of Set 3 | fort-shevchenko
# Processing Record 18 of Set 3 | mashhad
# Processing Record 19 of Set 3 | acari
# Processing Record 20 of Set 3 | saint-augustin
# Processing Record 21 of Set 3 | ormara
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | uruguaiana
# Processing Record 24 of Set 3 | igarka
# Processing Record 25 of Set 3 | axim
# Processing Record 26 of Set 3 | senador jose porfirio
# Processing Record 27 of Set 3 | severodvinsk
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | kargapolye
# City not found. Skipping...
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | komatipoort
# Processing Record 35 of Set 3 | bolobo
# Processing Record 36 of Set 3 | coruripe
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | lethem
# Processing Record 39 of Set 3 | sinnamary
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | balykshi
# Processing Record 43 of Set 3 | pultusk
# Processing Record 44 of Set 3 | arlit
# Processing Record 45 of Set 3 | belyy yar
# Processing Record 46 of Set 3 | leh
# Processing Record 47 of Set 3 | neuquen
# Processing Record 48 of Set 3 | mehamn
# Processing Record 49 of Set 3 | mezhdurechensk
# Processing Record 50 of Set 3 | arica
# Processing Record 1 of Set 4 | caravelas
# Processing Record 2 of Set 4 | andreapol
# Processing Record 3 of Set 4 | ibb
# Processing Record 4 of Set 4 | east london
# Processing Record 5 of Set 4 | saint-joseph
# Processing Record 6 of Set 4 | lokosovo
# Processing Record 7 of Set 4 | manyoni
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | henties bay
# Processing Record 11 of Set 4 | camopi
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | zanjan
# Processing Record 14 of Set 4 | jos
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | inta
# Processing Record 17 of Set 4 | uppsala
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | mitsamiouli
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | navalmoral de la mata
# Processing Record 22 of Set 4 | burica
# City not found. Skipping...
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | correntina
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | thinadhoo
# Processing Record 27 of Set 4 | georgiyevka
# Processing Record 28 of Set 4 | oriximina
# Processing Record 29 of Set 4 | moyale
# Processing Record 30 of Set 4 | la tuque
# Processing Record 31 of Set 4 | minab
# Processing Record 32 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 4 | bafata
# Processing Record 34 of Set 4 | vagur
# Processing Record 35 of Set 4 | aswan
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | lyubim
# Processing Record 38 of Set 4 | nioro
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | marquette
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | santa cruz
# Processing Record 45 of Set 4 | port shepstone
# Processing Record 46 of Set 4 | marsh harbour
# Processing Record 47 of Set 4 | glazov
# Processing Record 48 of Set 4 | angoche
# Processing Record 49 of Set 4 | mbanza-ngungu
# Processing Record 50 of Set 4 | kassala
# Processing Record 1 of Set 5 | zurrieq
# Processing Record 2 of Set 5 | kuito
# Processing Record 3 of Set 5 | touros
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | beloha
# Processing Record 6 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 5 | clarence town
# Processing Record 8 of Set 5 | maldonado
# Processing Record 9 of Set 5 | ituporanga
# Processing Record 10 of Set 5 | saint-louis
# Processing Record 11 of Set 5 | comodoro rivadavia
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | sambava
# Processing Record 14 of Set 5 | andilamena
# Processing Record 15 of Set 5 | kuryk
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | atbasar
# Processing Record 18 of Set 5 | alta floresta
# Processing Record 19 of Set 5 | vikravandi
# Processing Record 20 of Set 5 | aksarka
# Processing Record 21 of Set 5 | imbituba
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | kaka
# Processing Record 24 of Set 5 | najran
# Processing Record 25 of Set 5 | tazovskiy
# Processing Record 26 of Set 5 | nhlangano
# Processing Record 27 of Set 5 | guarapari
# Processing Record 28 of Set 5 | xai-xai
# Processing Record 29 of Set 5 | khuzdar
# Processing Record 30 of Set 5 | oleksandrivka
# Processing Record 31 of Set 5 | la labor
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | turayf
# Processing Record 34 of Set 5 | hamilton
# Processing Record 35 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 5 | bridlington
# Processing Record 37 of Set 5 | icatu
# Processing Record 38 of Set 5 | aripuana
# Processing Record 39 of Set 5 | uni
# Processing Record 40 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 5 | jesup
# Processing Record 42 of Set 5 | belgorod
# Processing Record 43 of Set 5 | anna paulowna
# Processing Record 44 of Set 5 | kalemie
# Processing Record 45 of Set 5 | sur
# Processing Record 46 of Set 5 | tromso
# Processing Record 47 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | tougue
# Processing Record 50 of Set 5 | mayskiy
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | san rafael
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | mega piston
# City not found. Skipping...
# Processing Record 5 of Set 6 | adamas
# Processing Record 6 of Set 6 | sihora
# Processing Record 7 of Set 6 | ambilobe
# Processing Record 8 of Set 6 | porto real do colegio
# Processing Record 9 of Set 6 | lebu
# Processing Record 10 of Set 6 | thunder bay
# Processing Record 11 of Set 6 | wanparti
# Processing Record 12 of Set 6 | pedreira
# Processing Record 13 of Set 6 | moose factory
# Processing Record 14 of Set 6 | gamba
# Processing Record 15 of Set 6 | hakkari
# Processing Record 16 of Set 6 | piacabucu
# Processing Record 17 of Set 6 | maragogi
# Processing Record 18 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 19 of Set 6 | itamaraca
# Processing Record 20 of Set 6 | ouesso
# Processing Record 21 of Set 6 | port hawkesbury
# Processing Record 22 of Set 6 | champaign
# Processing Record 23 of Set 6 | kashi
# Processing Record 24 of Set 6 | tias
# Processing Record 25 of Set 6 | bonthe
# Processing Record 26 of Set 6 | panjab
# Processing Record 27 of Set 6 | rochefort
# Processing Record 28 of Set 6 | balkhash
# Processing Record 29 of Set 6 | sao joao da barra
# Processing Record 30 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 6 | auray
# Processing Record 32 of Set 6 | chitral
# Processing Record 33 of Set 6 | fort wellington
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | siniscola
# Processing Record 36 of Set 6 | umba
# Processing Record 37 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 6 | aquin
# Processing Record 39 of Set 6 | maputo
# Processing Record 40 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 6 | abalak
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | pascagoula
# Processing Record 47 of Set 6 | saint-pierre
# Processing Record 48 of Set 6 | boa vista
# Processing Record 49 of Set 6 | mudigere
# Processing Record 50 of Set 6 | hualmay
# Processing Record 1 of Set 7 | batsfjord
# Processing Record 2 of Set 7 | zlobin
# Processing Record 3 of Set 7 | vestmanna
# Processing Record 4 of Set 7 | stromness
# Processing Record 5 of Set 7 | ajdabiya
# Processing Record 6 of Set 7 | numan
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | polovinnoye
# Processing Record 10 of Set 7 | cap-aux-meules
# Processing Record 11 of Set 7 | matagami
# Processing Record 12 of Set 7 | luanda
# Processing Record 13 of Set 7 | iracoubo
# Processing Record 14 of Set 7 | fredericton
# Processing Record 15 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 7 | oksfjord
# Processing Record 17 of Set 7 | sawakin
# Processing Record 18 of Set 7 | lieksa
# Processing Record 19 of Set 7 | sao filipe
# Processing Record 20 of Set 7 | tabora
# Processing Record 21 of Set 7 | krasnaya gorka
# Processing Record 22 of Set 7 | ayagoz
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | la serena
# Processing Record 25 of Set 7 | baracoa
# Processing Record 26 of Set 7 | banepa
# Processing Record 27 of Set 7 | atenas de san cristobal
# Processing Record 28 of Set 7 | mahibadhoo
# Processing Record 29 of Set 7 | caapucu
# Processing Record 30 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 7 | mstera
# Processing Record 32 of Set 7 | effingham
# Processing Record 33 of Set 7 | karpathos
# Processing Record 34 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 7 | cagli
# Processing Record 36 of Set 7 | chuy
# Processing Record 37 of Set 7 | marrakesh
# Processing Record 38 of Set 7 | salinas
# Processing Record 39 of Set 7 | aljezur
# Processing Record 40 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | tabatinga
# Processing Record 42 of Set 7 | krasnokholmskiy
# Processing Record 43 of Set 7 | kovur
# Processing Record 44 of Set 7 | songea
# Processing Record 45 of Set 7 | san vicente
# Processing Record 46 of Set 7 | asosa
# Processing Record 47 of Set 7 | mgandu
# Processing Record 48 of Set 7 | saint george
# Processing Record 49 of Set 7 | tucuman
# Processing Record 50 of Set 7 | zhezkazgan
# Processing Record 1 of Set 8 | vardo
# Processing Record 2 of Set 8 | muana
# Processing Record 3 of Set 8 | ordzhonikidze
# Processing Record 4 of Set 8 | roros
# Processing Record 5 of Set 8 | birao
# Processing Record 6 of Set 8 | teguise
# Processing Record 7 of Set 8 | seydi
# Processing Record 8 of Set 8 | miastko
# Processing Record 9 of Set 8 | neusiedl am see
# Processing Record 10 of Set 8 | korla
# Processing Record 11 of Set 8 | banda aceh
# Processing Record 12 of Set 8 | koundara
# Processing Record 13 of Set 8 | dalbandin
# Processing Record 14 of Set 8 | ornskoldsvik
# Processing Record 15 of Set 8 | qasigiannguit
# Processing Record 16 of Set 8 | san pedro
# Processing Record 17 of Set 8 | edgemere
# Processing Record 18 of Set 8 | abu dhabi
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | bunia
# Processing Record 21 of Set 8 | marzuq
# Processing Record 22 of Set 8 | hearst
# Processing Record 23 of Set 8 | mandra
# Processing Record 24 of Set 8 | wad rawah
# Processing Record 25 of Set 8 | aras
# Processing Record 26 of Set 8 | miloslavskoye
# Processing Record 27 of Set 8 | weligama
# Processing Record 28 of Set 8 | salinopolis
# Processing Record 29 of Set 8 | riberalta
# Processing Record 30 of Set 8 | sosnogorsk
# Processing Record 31 of Set 8 | namyslow
# Processing Record 32 of Set 8 | svetlogorsk
# Processing Record 33 of Set 8 | nalut
# Processing Record 34 of Set 8 | codrington
# Processing Record 35 of Set 8 | nova granada
# Processing Record 36 of Set 8 | talcahuano
# Processing Record 37 of Set 8 | gornopravdinsk
# Processing Record 38 of Set 8 | nantucket
# Processing Record 39 of Set 8 | beira
# Processing Record 40 of Set 8 | grindavik
# Processing Record 41 of Set 8 | viedma
# Processing Record 42 of Set 8 | miandoab
# Processing Record 43 of Set 8 | killybegs
# Processing Record 44 of Set 8 | richards bay
# Processing Record 45 of Set 8 | camacupa
# Processing Record 46 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 47 of Set 8 | scarborough
# Processing Record 48 of Set 8 | akureyri
# Processing Record 49 of Set 8 | sao joaquim
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | muscat
# Processing Record 2 of Set 9 | buchanan
# Processing Record 3 of Set 9 | giyon
# Processing Record 4 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | natal
# Processing Record 7 of Set 9 | talara
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | mulanje
# Processing Record 10 of Set 9 | falmouth
# Processing Record 11 of Set 9 | boden
# Processing Record 12 of Set 9 | plastunovskaya
# Processing Record 13 of Set 9 | betsiamites
# Processing Record 14 of Set 9 | aguimes
# Processing Record 15 of Set 9 | papagaios
# Processing Record 16 of Set 9 | sioux lookout
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | taperoa
# Processing Record 19 of Set 9 | presidencia roque saenz pena
# Processing Record 20 of Set 9 | margate
# Processing Record 21 of Set 9 | lac-megantic
# Processing Record 22 of Set 9 | krasnousolskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | passo de camaragibe
# Processing Record 24 of Set 9 | idritsa
# Processing Record 25 of Set 9 | hidiselu de sus
# Processing Record 26 of Set 9 | westport
# Processing Record 27 of Set 9 | kamenka
# Processing Record 28 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 9 | chor
# Processing Record 30 of Set 9 | kembe
# Processing Record 31 of Set 9 | maralal
# Processing Record 32 of Set 9 | lighthouse point
# Processing Record 33 of Set 9 | marystown
# Processing Record 34 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | gambela
# Processing Record 36 of Set 9 | perivolion
# Processing Record 37 of Set 9 | puerto varas
# Processing Record 38 of Set 9 | puerto leguizamo
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | raudeberg
# Processing Record 41 of Set 9 | guaruja
# Processing Record 42 of Set 9 | lubao
# Processing Record 43 of Set 9 | paita
# Processing Record 44 of Set 9 | road town
# Processing Record 45 of Set 9 | lusambo
# Processing Record 46 of Set 9 | magugu
# Processing Record 47 of Set 9 | uyuni
# Processing Record 48 of Set 9 | rawah
# Processing Record 49 of Set 9 | jalu
# Processing Record 50 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 1 of Set 10 | kerman
# Processing Record 2 of Set 10 | beberibe
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | nicoya
# Processing Record 5 of Set 10 | adre
# Processing Record 6 of Set 10 | surt
# Processing Record 7 of Set 10 | dovolnoye
# Processing Record 8 of Set 10 | constantine
# Processing Record 9 of Set 10 | alegrete
# Processing Record 10 of Set 10 | oranjestad
# Processing Record 11 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 10 | camana
# Processing Record 13 of Set 10 | krasnoselkup
# Processing Record 14 of Set 10 | hare bay
# Processing Record 15 of Set 10 | mingaora
# Processing Record 16 of Set 10 | turukhansk
# Processing Record 17 of Set 10 | bom jesus
# Processing Record 18 of Set 10 | tonj
# Processing Record 19 of Set 10 | mabaruma
# Processing Record 20 of Set 10 | brattvag
# Processing Record 21 of Set 10 | susehri
# Processing Record 22 of Set 10 | cambui
# Processing Record 23 of Set 10 | lerwick
# Processing Record 24 of Set 10 | kilindoni
# Processing Record 25 of Set 10 | lodwar
# Processing Record 26 of Set 10 | sabha
# Processing Record 27 of Set 10 | cerro largo
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | lima
# Processing Record 30 of Set 10 | arona
# Processing Record 31 of Set 10 | barbosa ferraz
# Processing Record 32 of Set 10 | zonguldak
# Processing Record 33 of Set 10 | radece
# Processing Record 34 of Set 10 | elesbao veloso
# Processing Record 35 of Set 10 | akdepe
# Processing Record 36 of Set 10 | nacala
# Processing Record 37 of Set 10 | mana
# Processing Record 38 of Set 10 | vuktyl
# Processing Record 39 of Set 10 | chicama
# Processing Record 40 of Set 10 | tarko-sale
# Processing Record 41 of Set 10 | male
# Processing Record 42 of Set 10 | roald
# Processing Record 43 of Set 10 | nouadhibou
# Processing Record 44 of Set 10 | coyah
# Processing Record 45 of Set 10 | eyl
# Processing Record 46 of Set 10 | opuwo
# Processing Record 47 of Set 10 | zelenogorskiy
# Processing Record 48 of Set 10 | acarau
# Processing Record 49 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 11 | bud
# Processing Record 2 of Set 11 | baglung
# Processing Record 3 of Set 11 | gameza
# Processing Record 4 of Set 11 | lasa
# Processing Record 5 of Set 11 | vikulovo
# Processing Record 6 of Set 11 | usinsk
# Processing Record 7 of Set 11 | uniao
# Processing Record 8 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | nuuk
# Processing Record 10 of Set 11 | quelimane
# Processing Record 11 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 11 | ampanihy
# Processing Record 13 of Set 11 | mananjary
# Processing Record 14 of Set 11 | marabba
# Processing Record 15 of Set 11 | luau
# Processing Record 16 of Set 11 | narsaq
# Processing Record 17 of Set 11 | nurota
# Processing Record 18 of Set 11 | udayagiri
# Processing Record 19 of Set 11 | gabu
# Processing Record 20 of Set 11 | ambikapur
# Processing Record 21 of Set 11 | evansville
# Processing Record 22 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 23 of Set 11 | svetlyy
# Processing Record 24 of Set 11 | grand-santi
# Processing Record 25 of Set 11 | voi
# Processing Record 26 of Set 11 | kikwit
# Processing Record 27 of Set 11 | valparaiso
# Processing Record 28 of Set 11 | totma
# Processing Record 29 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 11 | guhagar
# Processing Record 31 of Set 11 | srostki
# Processing Record 32 of Set 11 | kalininsk
# Processing Record 33 of Set 11 | isabela
# Processing Record 34 of Set 11 | francistown
# Processing Record 35 of Set 11 | boali
# Processing Record 36 of Set 11 | bardiyah
# Processing Record 37 of Set 11 | port-gentil
# Processing Record 38 of Set 11 | garissa
# Processing Record 39 of Set 11 | impfondo
# Processing Record 40 of Set 11 | choma
# Processing Record 41 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 11 | kolarovo
# Processing Record 43 of Set 11 | quatre cocos
# Processing Record 44 of Set 11 | norilsk
# Processing Record 45 of Set 11 | santiago
# Processing Record 46 of Set 11 | savannah bight
# Processing Record 47 of Set 11 | baherden
# Processing Record 48 of Set 11 | abha
# Processing Record 49 of Set 11 | jorochito
# Processing Record 50 of Set 11 | kharp
# Processing Record 1 of Set 12 | ayna
# Processing Record 2 of Set 12 | labytnangi
# Processing Record 3 of Set 12 | gayeri
# Processing Record 4 of Set 12 | anzio
# Processing Record 5 of Set 12 | reconquista
# Processing Record 6 of Set 12 | moura
# Processing Record 7 of Set 12 | vizinga
# Processing Record 8 of Set 12 | kralendijk
# Processing Record 9 of Set 12 | san ignacio
# Processing Record 10 of Set 12 | kentau
# Processing Record 11 of Set 12 | keti bandar
# Processing Record 12 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 12 | hanko
# Processing Record 14 of Set 12 | ludwigslust
# Processing Record 15 of Set 12 | farafangana
# Processing Record 16 of Set 12 | pitimbu
# Processing Record 17 of Set 12 | cochrane
# Processing Record 18 of Set 12 | piranshahr
# Processing Record 19 of Set 12 | mahuva
# Processing Record 20 of Set 12 | bonavista
# Processing Record 21 of Set 12 | gobabis
# Processing Record 22 of Set 12 | langres
# Processing Record 23 of Set 12 | saint andrews
# Processing Record 24 of Set 12 | andra
# Processing Record 25 of Set 12 | santa vitoria do palmar
# Processing Record 26 of Set 12 | sistranda
# Processing Record 27 of Set 12 | shakiso
# Processing Record 28 of Set 12 | khorixas
# Processing Record 29 of Set 12 | kibaya
# Processing Record 30 of Set 12 | afogados da ingazeira
# Processing Record 31 of Set 12 | ponta delgada
# Processing Record 32 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 33 of Set 12 | zenzeli
# Processing Record 34 of Set 12 | brae
# Processing Record 35 of Set 12 | porto de moz
# Processing Record 36 of Set 12 | pathanamthitta
# Processing Record 37 of Set 12 | lapa
# Processing Record 38 of Set 12 | karpogory
# Processing Record 39 of Set 12 | panguipulli
# Processing Record 40 of Set 12 | redan
# Processing Record 41 of Set 12 | nova olimpia
# Processing Record 42 of Set 12 | san juan
# Processing Record 43 of Set 12 | forestville
# Processing Record 44 of Set 12 | honavar
# Processing Record 45 of Set 12 | itigi
# Processing Record 46 of Set 12 | padang
# Processing Record 47 of Set 12 | savelugu
# Processing Record 48 of Set 12 | bull savanna
# Processing Record 49 of Set 12 | zwedru
# Processing Record 50 of Set 12 | kulu
# Processing Record 1 of Set 13 | praia
# Processing Record 2 of Set 13 | aksu
# Processing Record 3 of Set 13 | pietersburg
# Processing Record 4 of Set 13 | port blair
# Processing Record 5 of Set 13 | lyuban
# Processing Record 6 of Set 13 | zanzibar
# Processing Record 7 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 13 | west bay
# Processing Record 9 of Set 13 | shalya
# Processing Record 10 of Set 13 | maniitsoq
# Processing Record 11 of Set 13 | khorlovo
# Processing Record 12 of Set 13 | kudahuvadhoo
# Processing Record 13 of Set 13 | kiruna
# Processing Record 14 of Set 13 | mineiros
# Processing Record 15 of Set 13 | yuzhno-sukhokumsk
# Processing Record 16 of Set 13 | bid
# City not found. Skipping...
# Processing Record 17 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 13 | khorramshahr
# Processing Record 19 of Set 13 | radyvyliv
# Processing Record 20 of Set 13 | thompson
# Processing Record 21 of Set 13 | kangaatsiaq
# Processing Record 22 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 13 | rabo de peixe
# Processing Record 24 of Set 13 | yar-sale
# Processing Record 25 of Set 13 | harare
# Processing Record 26 of Set 13 | le port
# Processing Record 27 of Set 13 | solvychegodsk
# Processing Record 28 of Set 13 | iralaya
# Processing Record 29 of Set 13 | maku
# Processing Record 30 of Set 13 | huarmey
# Processing Record 31 of Set 13 | dinard
# Processing Record 32 of Set 13 | botad
# Processing Record 33 of Set 13 | berlevag
# Processing Record 34 of Set 13 | aranos
# Processing Record 35 of Set 13 | riyadh
# Processing Record 36 of Set 13 | tema
# Processing Record 37 of Set 13 | sechura
# Processing Record 38 of Set 13 | aketi
# Processing Record 39 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 13 | hargeysa
# Processing Record 41 of Set 13 | benavente
# Processing Record 42 of Set 13 | taveta
# Processing Record 43 of Set 13 | yining
# Processing Record 44 of Set 13 | biu
# Processing Record 45 of Set 13 | norrtalje
# Processing Record 46 of Set 13 | hambantota
# Processing Record 47 of Set 13 | santo domingo
# Processing Record 48 of Set 13 | williamsburg
# Processing Record 49 of Set 13 | sovetskiy
# Processing Record 50 of Set 13 | chabahar
# Processing Record 1 of Set 14 | saint anthony
# Processing Record 2 of Set 14 | vigeland
# Processing Record 3 of Set 14 | kinkala
# Processing Record 4 of Set 14 | banfora
# Processing Record 5 of Set 14 | coventry
# Processing Record 6 of Set 14 | pishin
# Processing Record 7 of Set 14 | carbonia
# Processing Record 8 of Set 14 | birjand
# Processing Record 9 of Set 14 | iguape
# Processing Record 10 of Set 14 | stornoway
# Processing Record 11 of Set 14 | qafqafa
# Processing Record 12 of Set 14 | dioknisi
# Processing Record 13 of Set 14 | tignere
# Processing Record 14 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 15 of Set 14 | yarada
# Processing Record 16 of Set 14 | boralday
# Processing Record 17 of Set 14 | nsanje
# Processing Record 18 of Set 14 | sayat
# Processing Record 19 of Set 14 | bereda
# Processing Record 20 of Set 14 | mamallapuram
# Processing Record 21 of Set 14 | mulatupo
# Processing Record 22 of Set 14 | valdivia
# Processing Record 23 of Set 14 | brigantine
# Processing Record 24 of Set 14 | la romana
# Processing Record 25 of Set 14 | konotop
# Processing Record 26 of Set 14 | zambezi
# Processing Record 27 of Set 14 | malindi
# Processing Record 28 of Set 14 | teguldet
# Processing Record 29 of Set 14 | omboue
# Processing Record 30 of Set 14 | pucara
# Processing Record 31 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 14 | barcelos
# Processing Record 33 of Set 14 | hennenman
# Processing Record 34 of Set 14 | zhuravka
# Processing Record 35 of Set 14 | japura
# Processing Record 36 of Set 14 | ibra
# Processing Record 37 of Set 14 | havre-saint-pierre
# Processing Record 38 of Set 14 | bathsheba
# Processing Record 39 of Set 14 | lujan
# Processing Record 40 of Set 14 | uige
# Processing Record 41 of Set 14 | gumia
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | bulawayo
# Processing Record 44 of Set 14 | olinda
# Processing Record 45 of Set 14 | eirunepe
# Processing Record 46 of Set 14 | isla mujeres
# Processing Record 47 of Set 14 | santa vitoria
# Processing Record 48 of Set 14 | herat
# Processing Record 49 of Set 14 | limanowa
# Processing Record 50 of Set 14 | kemijarvi
# Processing Record 1 of Set 15 | ballina
# Processing Record 2 of Set 15 | mongo
# Processing Record 3 of Set 15 | dudinka
# Processing Record 4 of Set 15 | port-cartier
# Processing Record 5 of Set 15 | los llanos de aridane
# Processing Record 6 of Set 15 | arkadak
# Processing Record 7 of Set 15 | wawa
# Processing Record 8 of Set 15 | joao pinheiro
# Processing Record 9 of Set 15 | cefalu
# Processing Record 10 of Set 15 | fraga
# Processing Record 11 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 15 | doha
# Processing Record 14 of Set 15 | neyshabur
# Processing Record 15 of Set 15 | rio grande
# Processing Record 16 of Set 15 | la macarena
# Processing Record 17 of Set 15 | gazalkent
# Processing Record 18 of Set 15 | salta
# Processing Record 19 of Set 15 | den helder
# Processing Record 20 of Set 15 | portree
# Processing Record 21 of Set 15 | verkhnedneprovskiy
# Processing Record 22 of Set 15 | durusu
# Processing Record 23 of Set 15 | soldatskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | inirida
# Processing Record 25 of Set 15 | dieppe bay
# City not found. Skipping...
# Processing Record 26 of Set 15 | kiri buru
# Processing Record 27 of Set 15 | vienne
# Processing Record 28 of Set 15 | tokmak
# Processing Record 29 of Set 15 | taltal
# Processing Record 30 of Set 15 | lewisporte
# Processing Record 31 of Set 15 | iquitos
# Processing Record 32 of Set 15 | tena
# Processing Record 33 of Set 15 | rawson
# Processing Record 34 of Set 15 | antalaha
# Processing Record 35 of Set 15 | ramotswa
# Processing Record 36 of Set 15 | moissala
# Processing Record 37 of Set 15 | taoudenni
# Processing Record 38 of Set 15 | mazsalaca
# Processing Record 39 of Set 15 | mogadishu
# Processing Record 40 of Set 15 | havelock
# Processing Record 41 of Set 15 | puerto del rosario
# Processing Record 42 of Set 15 | jamame
# Processing Record 43 of Set 15 | dalvik
# Processing Record 44 of Set 15 | ryomgard
# Processing Record 45 of Set 15 | makat
# Processing Record 46 of Set 15 | araouane
# Processing Record 47 of Set 15 | skibbereen
# Processing Record 48 of Set 15 | porbandar
# Processing Record 49 of Set 15 | santa isabel do rio negro
# Processing Record 50 of Set 15 | verkhnyaya toyma
# Processing Record 1 of Set 16 | pimentel
# Processing Record 2 of Set 16 | butembo
# Processing Record 3 of Set 16 | floro
# Processing Record 4 of Set 16 | bodden town
# Processing Record 5 of Set 16 | puerto concordia
# Processing Record 6 of Set 16 | ambanja
# Processing Record 7 of Set 16 | rincon
# Processing Record 8 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 16 | alindao
# Processing Record 10 of Set 16 | ciras
# City not found. Skipping...
# Processing Record 11 of Set 16 | gweru
# Processing Record 12 of Set 16 | carnarvon
# Processing Record 13 of Set 16 | vila do maio
# Processing Record 14 of Set 16 | la rioja
# Processing Record 15 of Set 16 | maykain
# City not found. Skipping...
# Processing Record 16 of Set 16 | shieli
# Processing Record 17 of Set 16 | candido mendes
# Processing Record 18 of Set 16 | mattru
# Processing Record 19 of Set 16 | swellendam
# Processing Record 20 of Set 16 | porto belo
# Processing Record 21 of Set 16 | tessalit
# Processing Record 22 of Set 16 | nova gradiska
# Processing Record 23 of Set 16 | moron
# Processing Record 24 of Set 16 | kita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Suamico  44.6319 -88.0393     59.77        51           0        5.75
# 1      Bartica   6.4000 -58.6167     89.92        53          64        4.36
# 2        Bilma  18.6853  12.9164     76.03        21           0        9.69
# 3  Bronnoysund  65.4625  12.1997     46.40        93          75       10.36
# 4     Key West  24.5557 -81.7826     91.40        74          20       11.50
# 5   Pervomaysk  48.0443  30.8507     51.03        78         100        4.09
# 6     Hermanus -34.4187  19.2345     62.80        79          84       15.79
# 7        Muros  42.7762  -9.0603     64.09        89         100       20.94
# 8      Cayenne   4.9333 -52.3333     84.24        79           0       11.50
# 9      Paamiut  61.9940 -49.6678     35.02        96         100       15.86
#
#   Country                 Date Current Description
# 0      US  2022-10-28 20:16:46           clear sky
# 1      GY  2022-10-28 20:16:48       broken clouds
# 2      NE  2022-10-28 20:16:48           clear sky
# 3      NO  2022-10-28 20:16:49       broken clouds
# 4      US  2022-10-28 20:15:18          few clouds
# 5      UA  2022-10-28 20:16:49     overcast clouds
# 6      ZA  2022-10-28 20:16:50       broken clouds
# 7      ES  2022-10-28 20:16:50       moderate rain
# 8      GF  2022-10-28 20:16:51           clear sky
# 9      GL  2022-10-28 20:16:51                snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat      Lng  Max Temp  \
# 0      Suamico      US  2022-10-28 20:16:46  44.6319 -88.0393     59.77
# 1      Bartica      GY  2022-10-28 20:16:48   6.4000 -58.6167     89.92
# 2        Bilma      NE  2022-10-28 20:16:48  18.6853  12.9164     76.03
# 3  Bronnoysund      NO  2022-10-28 20:16:49  65.4625  12.1997     46.40
# 4     Key West      US  2022-10-28 20:15:18  24.5557 -81.7826     91.40
# 5   Pervomaysk      UA  2022-10-28 20:16:49  48.0443  30.8507     51.03
# 6     Hermanus      ZA  2022-10-28 20:16:50 -34.4187  19.2345     62.80
# 7        Muros      ES  2022-10-28 20:16:50  42.7762  -9.0603     64.09
# 8      Cayenne      GF  2022-10-28 20:16:51   4.9333 -52.3333     84.24
# 9      Paamiut      GL  2022-10-28 20:16:51  61.9940 -49.6678     35.02
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        51           0        5.75           clear sky
# 1        53          64        4.36       broken clouds
# 2        21           0        9.69           clear sky
# 3        93          75       10.36       broken clouds
# 4        74          20       11.50          few clouds
# 5        78         100        4.09     overcast clouds
# 6        79          84       15.79       broken clouds
# 7        89         100       20.94       moderate rain
# 8        79           0       11.50           clear sky
# 9        96         100       15.86                snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = " WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="Index")
